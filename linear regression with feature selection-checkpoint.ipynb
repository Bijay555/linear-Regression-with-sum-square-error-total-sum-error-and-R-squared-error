# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets,linear_model
boston_data=datasets.load_boston()
df = pd.DataFrame(data=boston_data['data'], columns=boston_data.feature_names)

print(df.head())
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
df['PRICE']=boston_data.target
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  PRICE
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets,linear_model
correlation_matrix=df.corr().round(2)

sns.heatmap(data=correlation_matrix,annot=True)

# %%
import numpy as np 
import matplotlib.pyplot as plt 
  
def estimate_coef(x, y): 
    # number of observations/points 
    n = np.size(x) 
  
    # mean of x and y vector 
    m_x, m_y = np.mean(x), np.mean(y) 
  
    # calculating cross-deviation and deviation about x 
    SS_xy = np.sum(y*x) - n*m_y*m_x 
    SS_xx = np.sum(x*x) - n*m_x*m_x 
  
    # calculating regression coefficients 
    b_1 = SS_xy / SS_xx 
    b_0 = m_y - b_1*m_x 
  
    return(b_0, b_1) 
  
def plot_regression_line(x, y, b): 
    # plotting the actual points as scatter plot 
    plt.scatter(x, y, color = "m", 
               marker = "o", s = 30) 
  
    # predicted response vector 
    y_pred = b[0] + b[1]*x
    
    # plotting the regression line 
    plt.plot(x, y_pred, color = "g") 
  
    # putting labels 
    plt.xlabel('x') 
    plt.ylabel('y') 
  
    # function to show plot 
    plt.show()
    
def sum_square_error(y,y_pred):
    l=len(y)
    for i in range(l):
        sse=np.sum((y[i]-y_pred[i])**2)
    return sse

def total_sum_squared_error(y,m_y):
    l=len(y)
    for i in range(l):
        sst=np.sum((y[i]-m_y)**2)
    return sst

def r_squared(sse,sst):
    r=1-sse/sst
    return r

    
  
def main(): 
    # observations
     
    x = df.LSTAT
    y = df.PRICE
    y_pred=[]
    l=len(x)
    # estimating coefficients 
    b = estimate_coef(x, y) 
    print("Estimated coefficients:\nb_0 = {}   \nb_1 = {}".format(b[0], b[1]))
    n = np.size(x)
    for i in range(n):
        y_predict = b[0] + b[1]*x
        y_pred.append(y_predict)
    m_y=np.mean(y)
    
    # plotting regression line 
    plot_regression_line(x, y, b) 
    
    #predicting sum square error
    s=sum_square_error(y,y_pred)
    print("Sum square error:",s)
    
    #predicting total sum square error
    st=total_sum_squared_error(y, m_y)
    print("Total sum square error:",st)
    
    #prdicting r_squared value
    r = r_squared(s,st)
    print("R squared value:",r)
  
if __name__ == "__main__": 
    main()
# Out:
# Estimated coefficients:
# b_0 = 34.553840879383316
# b_1 = -0.9500493537580056
# Sum square error: 80450.53858167453
# Total sum square error: 113.05657032604844
# R squared value: -710.5954282856799
